# %% [markdown]
# #MOBILE AND LAPTOP SALES DATA

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/mobile_sales_data.csv")

# %%
df.head()
# Out:
#         Product      Brand Product Code  \
# 0  Mobile Phone   Motorola     88EB4558
# 1        Laptop       Oppo     416DFEEB
# 2  Mobile Phone    Samsung     9F975B08
# 3        Laptop       Sony     73D2A7CC
# 4        Laptop  Microsoft     CCE0B80D
#
#                                Product Specification   Price Inward Date  \
# 0  Site candidate activity company there bit insi...   78570  02-08-2023
# 1            Beat put care fight affect address his.   44613  03-10-2023
# 2           Energy special low seven place audience.  159826  19-03-2025
# 3  Friend record hard contain minute we role sea ...   20911  06-02-2024
# 4   Program recently feeling save tree hotel people.   69832  10-08-2023
#
#   Dispatch Date  Quantity Sold  Customer Name Customer Location   Region  \
# 0    03-08-2023              6   William Hess      South Kelsey  Central
# 1    06-10-2023              1    Larry Smith        North Lisa    South
# ...

# %%
df.tail()
# Out:
#             Product     Brand Product Code  \
# 49995        Laptop  Motorola     8C187637
# 49996        Laptop        HP     0DA9E4D3
# 49997        Laptop   Toshiba     CAD89A93
# 49998  Mobile Phone    Lenovo     78566C17
# 49999        Laptop      Asus     9C3FC57C
#
#                                    Product Specification   Price Inward Date  \
# 49995            Pick build kind teach mean each camera.  170385  02-03-2024
# 49996       Outside policy treat he opportunity pattern.  193133  19-01-2025
# 49997  Test floor tax together out adult discover own...   66502  16-01-2024
# 49998               Away also magazine receive such lay.  158883  15-05-2023
# 49999      Role ahead common listen idea few blood half.   86483  29-08-2023
#
#       Shipment Date  Quantity Sold      Customer Name      Customer Location  \
# 49995    11-04-2024              6         Sara Gomez             Sylviatown
# 49996    20-01-2025              4      Raymond Clark             Chrismouth
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product                  50000 non-null  object
#  1   Brand                    50000 non-null  object
#  2   Product Code             50000 non-null  object
#  3   Product Specification    50000 non-null  object
#  4   Price                    50000 non-null  int64
#  5   Inward Date              50000 non-null  object
#  6   Dispatch Date            50000 non-null  object
#  7   Quantity Sold            50000 non-null  int64
#  8   Customer Name            50000 non-null  object
#  9   Customer Location        50000 non-null  object
#  10  Region                   50000 non-null  object
#  11  Core Specification       25017 non-null  object
#  12  Processor Specification  50000 non-null  object
#  13  RAM                      50000 non-null  object
# ...

# %%
df.describe()
# Out:
#                Price  Quantity Sold
# count   50000.000000    50000.00000
# mean   102641.407080        5.51378
# std     56363.550361        2.88101
# min      5008.000000        1.00000
# 25%     53487.000000        3.00000
# 50%    103072.000000        6.00000
# 75%    151396.250000        8.00000
# max    199999.000000       10.00000

# %%
df.isnull().sum()
# Out:
# Product                        0
# Brand                          0
# Product Code                   0
# Product Specification          0
# Price                          0
# Inward Date                    0
# Dispatch Date                  0
# Quantity Sold                  0
# Customer Name                  0
# Customer Location              0
# Region                         0
# Core Specification         24983
# Processor Specification        0
# RAM                            0
# ROM                            0
# SSD                        24983
# dtype: int64

# %%
df['Core Specification']=df['Core Specification'].fillna("0")

# %%
df['SSD'] = df['SSD'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Product                    0
# Brand                      0
# Product Code               0
# Product Specification      0
# Price                      0
# Inward Date                0
# Dispatch Date              0
# Quantity Sold              0
# Customer Name              0
# Customer Location          0
# Region                     0
# Core Specification         0
# Processor Specification    0
# RAM                        0
# ROM                        0
# SSD                        0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
print("Remaining duplicates:",df.duplicated().sum())
# Out:
# Remaining duplicates: 0

# %%
#Rename a specific column
df = df.rename(columns = {"Dispatch Date":"Shipment Date"})

# %%
print(df.columns)
# Out:
# Index(['Product', 'Brand', 'Product Code', 'Product Specification', 'Price',
#        'Inward Date', 'Shipment Date', 'Quantity Sold', 'Customer Name',
#        'Customer Location', 'Region', 'Core Specification',
#        'Processor Specification', 'RAM', 'ROM', 'SSD'],
#       dtype='object')
